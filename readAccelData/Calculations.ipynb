# %%
from functionTools import *
import numpy as np

# %%
x = [i for i in range(int(100*np.pi))]
y = [np.sin(i/10) for i in x]
plot(x,y,"x","y=x^2")

# %%
f = np.fft.rfft(y)
freq = np.fft.fftfreq(f.shape[-1])
plot(freq,np.abs(f))
